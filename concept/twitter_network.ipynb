# %%
import networkx as nx
import random
import numpy
from collections import deque
import csv
from threading import Thread
from Queue import Queue

# %%
def parse_twitter_users():
    # return: ({ user: followers (#out) }, { user: following (#in) })
    outdegrees = dict()
    indegrees = dict()
    with open('twitter-analysis/users.csv', 'r', encoding='utf-8') as f:
        reader = csv.reader(f)
        next(reader) # skip header
        for row in reader:
            if not row or row[0] == '':
                continue
            user_id = row[0]
            outdegree = row[13]
            indegree = row[14]
            outdegrees[user_id] = outdegree
            indegrees[user_id] = indegree

    return set(outdegrees.keys()), outdegrees, indegrees

# %%
users, followers, following = parse_twitter_users()
# print(users)
# print(outdegrees)

# %%
def build_twitter_network(users, outdegrees, indegrees):
    edges = { user:[] for user in users }
    down_counter = indegrees.copy()
    
    # for each user, populate its followers
    for idx, user in enumerate(list(users)):
        
        if idx % 100 == 0 and idx > 0:
            print('finished building followers for %d users' % idx)
        
        # for each follower count, select a follower, dec their indegree
        followers = int(outdegrees[user])
        for follower in range(followers):
            
            if follower % 100 == 0 and follower > 0:
                print('-------- CHECKPOINT --------> finished {0}/{1} on user {2}'.format(follower, followers, idx))
            
            selected = False
            while not selected:
                
                # should get invoked last, when we finally run out
                if down_counter.keys() == []:
                    print('RAN OUT OF USERS TO ASSIGN')
                    return edges
                
                new_follower = random.choice(list(down_counter.keys()))
                if int(down_counter[new_follower]) > 0:
                    edges[user].append(new_follower)
                    down_counter[new_follower] = int(down_counter[new_follower]) - 1
                    if down_counter[new_follower] == 0:
                        del down_counter[new_follower]
                    selected = True
                else:
                    continue
                
    return edges

# %%
users, followers, following = parse_twitter_users()
print('building network now...')
edges = build_twitter_network(users, followers, following)
# Out:
# building network now...
# -------- CHECKPOINT --------> finished 100/1067 on user 4
# -------- CHECKPOINT --------> finished 200/1067 on user 4
# -------- CHECKPOINT --------> finished 300/1067 on user 4
# -------- CHECKPOINT --------> finished 400/1067 on user 4
# -------- CHECKPOINT --------> finished 500/1067 on user 4
# -------- CHECKPOINT --------> finished 600/1067 on user 4
# -------- CHECKPOINT --------> finished 700/1067 on user 4
# -------- CHECKPOINT --------> finished 800/1067 on user 4
# -------- CHECKPOINT --------> finished 900/1067 on user 4
# -------- CHECKPOINT --------> finished 1000/1067 on user 4
# -------- CHECKPOINT --------> finished 100/102 on user 27
# -------- CHECKPOINT --------> finished 100/161 on user 32
# -------- CHECKPOINT --------> finished 100/184 on user 40
# -------- CHECKPOINT --------> finished 100/289 on user 45
# -------- CHECKPOINT --------> finished 200/289 on user 45
# -------- CHECKPOINT --------> finished 100/271 on user 46
# -------- CHECKPOINT --------> finished 200/271 on user 46
# -------- CHECKPOINT --------> finished 100/194 on user 55
# -------- CHECKPOINT --------> finished 100/142 on user 59
# -------- CHECKPOINT --------> finished 100/291 on user 65
# -------- CHECKPOINT --------> finished 200/291 on user 65
# -------- CHECKPOINT --------> finished 100/138 on user 67
# -------- CHECKPOINT --------> finished 100/3040 on user 76
# -------- CHECKPOINT --------> finished 200/3040 on user 76
# -------- CHECKPOINT --------> finished 300/3040 on user 76
# -------- CHECKPOINT --------> finished 400/3040 on user 76
# -------- CHECKPOINT --------> finished 500/3040 on user 76
# -------- CHECKPOINT --------> finished 600/3040 on user 76
# -------- CHECKPOINT --------> finished 700/3040 on user 76
# -------- CHECKPOINT --------> finished 800/3040 on user 76
# -------- CHECKPOINT --------> finished 900/3040 on user 76
# -------- CHECKPOINT --------> finished 1000/3040 on user 76
# -------- CHECKPOINT --------> finished 1100/3040 on user 76
# -------- CHECKPOINT --------> finished 1200/3040 on user 76
# -------- CHECKPOINT --------> finished 1300/3040 on user 76
# -------- CHECKPOINT --------> finished 1400/3040 on user 76
# -------- CHECKPOINT --------> finished 1500/3040 on user 76
# -------- CHECKPOINT --------> finished 1600/3040 on user 76
# -------- CHECKPOINT --------> finished 1700/3040 on user 76
# -------- CHECKPOINT --------> finished 1800/3040 on user 76
# -------- CHECKPOINT --------> finished 1900/3040 on user 76
# -------- CHECKPOINT --------> finished 2000/3040 on user 76
# -------- CHECKPOINT --------> finished 2100/3040 on user 76
# -------- CHECKPOINT --------> finished 2200/3040 on user 76
# -------- CHECKPOINT --------> finished 2300/3040 on user 76
# -------- CHECKPOINT --------> finished 2400/3040 on user 76
# -------- CHECKPOINT --------> finished 2500/3040 on user 76
# -------- CHECKPOINT --------> finished 2600/3040 on user 76
# -------- CHECKPOINT --------> finished 2700/3040 on user 76
# -------- CHECKPOINT --------> finished 2800/3040 on user 76
# -------- CHECKPOINT --------> finished 2900/3040 on user 76
# -------- CHECKPOINT --------> finished 3000/3040 on user 76
# -------- CHECKPOINT --------> finished 100/141 on user 77
# -------- CHECKPOINT --------> finished 100/144 on user 80
# -------- CHECKPOINT --------> finished 100/168 on user 85
# -------- CHECKPOINT --------> finished 100/330 on user 86
# -------- CHECKPOINT --------> finished 200/330 on user 86
# -------- CHECKPOINT --------> finished 300/330 on user 86
# -------- CHECKPOINT --------> finished 100/105 on user 99
# finished building followers for 100 users
# -------- CHECKPOINT --------> finished 100/291 on user 108
# -------- CHECKPOINT --------> finished 200/291 on user 108
# -------- CHECKPOINT --------> finished 100/136 on user 114
# -------- CHECKPOINT --------> finished 100/425 on user 122
# -------- CHECKPOINT --------> finished 200/425 on user 122
# -------- CHECKPOINT --------> finished 300/425 on user 122
# -------- CHECKPOINT --------> finished 400/425 on user 122
# -------- CHECKPOINT --------> finished 100/115 on user 137
# -------- CHECKPOINT --------> finished 100/275 on user 151
# -------- CHECKPOINT --------> finished 200/275 on user 151
# -------- CHECKPOINT --------> finished 100/912 on user 160
# -------- CHECKPOINT --------> finished 200/912 on user 160
# -------- CHECKPOINT --------> finished 300/912 on user 160
# -------- CHECKPOINT --------> finished 400/912 on user 160
# -------- CHECKPOINT --------> finished 500/912 on user 160
# -------- CHECKPOINT --------> finished 600/912 on user 160
# -------- CHECKPOINT --------> finished 700/912 on user 160
# -------- CHECKPOINT --------> finished 800/912 on user 160
# -------- CHECKPOINT --------> finished 900/912 on user 160
# -------- CHECKPOINT --------> finished 100/689 on user 165
# -------- CHECKPOINT --------> finished 200/689 on user 165
# -------- CHECKPOINT --------> finished 300/689 on user 165
# -------- CHECKPOINT --------> finished 400/689 on user 165
# -------- CHECKPOINT --------> finished 500/689 on user 165
# -------- CHECKPOINT --------> finished 600/689 on user 165
# -------- CHECKPOINT --------> finished 100/121 on user 176
# finished building followers for 200 users
# -------- CHECKPOINT --------> finished 100/183 on user 217
# -------- CHECKPOINT --------> finished 100/103 on user 233
# -------- CHECKPOINT --------> finished 100/127 on user 241
# -------- CHECKPOINT --------> finished 100/669 on user 252
# -------- CHECKPOINT --------> finished 200/669 on user 252
# -------- CHECKPOINT --------> finished 300/669 on user 252
# -------- CHECKPOINT --------> finished 400/669 on user 252
# -------- CHECKPOINT --------> finished 500/669 on user 252
# -------- CHECKPOINT --------> finished 600/669 on user 252
# -------- CHECKPOINT --------> finished 100/251 on user 273
# -------- CHECKPOINT --------> finished 200/251 on user 273
# finished building followers for 300 users
# -------- CHECKPOINT --------> finished 100/371 on user 313
# -------- CHECKPOINT --------> finished 200/371 on user 313
# -------- CHECKPOINT --------> finished 300/371 on user 313
# -------- CHECKPOINT --------> finished 100/234 on user 319
# -------- CHECKPOINT --------> finished 200/234 on user 319
# -------- CHECKPOINT --------> finished 100/177 on user 322
# -------- CHECKPOINT --------> finished 100/260 on user 324
# -------- CHECKPOINT --------> finished 200/260 on user 324
# -------- CHECKPOINT --------> finished 100/222 on user 326
# -------- CHECKPOINT --------> finished 200/222 on user 326
# -------- CHECKPOINT --------> finished 100/309 on user 332
# -------- CHECKPOINT --------> finished 200/309 on user 332
# -------- CHECKPOINT --------> finished 300/309 on user 332
# -------- CHECKPOINT --------> finished 100/148 on user 335
# -------- CHECKPOINT --------> finished 100/113 on user 341
# -------- CHECKPOINT --------> finished 100/102 on user 377
# finished building followers for 400 users
# -------- CHECKPOINT --------> finished 100/135 on user 406
# -------- CHECKPOINT --------> finished 100/164 on user 416
# -------- CHECKPOINT --------> finished 100/122 on user 437
# -------- CHECKPOINT --------> finished 100/282 on user 470
# -------- CHECKPOINT --------> finished 200/282 on user 470
# -------- CHECKPOINT --------> finished 100/154 on user 476
# -------- CHECKPOINT --------> finished 100/414 on user 480
# -------- CHECKPOINT --------> finished 200/414 on user 480
# -------- CHECKPOINT --------> finished 300/414 on user 480
# -------- CHECKPOINT --------> finished 400/414 on user 480
# finished building followers for 500 users
# -------- CHECKPOINT --------> finished 100/114 on user 524
# -------- CHECKPOINT --------> finished 100/207 on user 532
# -------- CHECKPOINT --------> finished 200/207 on user 532
# -------- CHECKPOINT --------> finished 100/375 on user 544
# -------- CHECKPOINT --------> finished 200/375 on user 544
# -------- CHECKPOINT --------> finished 300/375 on user 544
# -------- CHECKPOINT --------> finished 100/160 on user 550
# -------- CHECKPOINT --------> finished 100/245 on user 565
# -------- CHECKPOINT --------> finished 200/245 on user 565
# -------- CHECKPOINT --------> finished 100/519 on user 597
# -------- CHECKPOINT --------> finished 200/519 on user 597
# -------- CHECKPOINT --------> finished 300/519 on user 597
# -------- CHECKPOINT --------> finished 400/519 on user 597
# -------- CHECKPOINT --------> finished 500/519 on user 597
# -------- CHECKPOINT --------> finished 100/110 on user 598
# finished building followers for 600 users
# -------- CHECKPOINT --------> finished 100/153 on user 613
# -------- CHECKPOINT --------> finished 100/7131 on user 617
# -------- CHECKPOINT --------> finished 200/7131 on user 617
# -------- CHECKPOINT --------> finished 300/7131 on user 617
# -------- CHECKPOINT --------> finished 400/7131 on user 617
# -------- CHECKPOINT --------> finished 500/7131 on user 617
# -------- CHECKPOINT --------> finished 600/7131 on user 617
# -------- CHECKPOINT --------> finished 700/7131 on user 617
# -------- CHECKPOINT --------> finished 800/7131 on user 617
# -------- CHECKPOINT --------> finished 900/7131 on user 617
# -------- CHECKPOINT --------> finished 1000/7131 on user 617
# -------- CHECKPOINT --------> finished 1100/7131 on user 617
# -------- CHECKPOINT --------> finished 1200/7131 on user 617
# -------- CHECKPOINT --------> finished 1300/7131 on user 617
# -------- CHECKPOINT --------> finished 1400/7131 on user 617
# -------- CHECKPOINT --------> finished 1500/7131 on user 617
# -------- CHECKPOINT --------> finished 1600/7131 on user 617
# -------- CHECKPOINT --------> finished 1700/7131 on user 617
# -------- CHECKPOINT --------> finished 1800/7131 on user 617
# -------- CHECKPOINT --------> finished 1900/7131 on user 617
# -------- CHECKPOINT --------> finished 2000/7131 on user 617
# -------- CHECKPOINT --------> finished 2100/7131 on user 617
# -------- CHECKPOINT --------> finished 2200/7131 on user 617
# -------- CHECKPOINT --------> finished 2300/7131 on user 617
# -------- CHECKPOINT --------> finished 2400/7131 on user 617
# -------- CHECKPOINT --------> finished 2500/7131 on user 617
# -------- CHECKPOINT --------> finished 2600/7131 on user 617
# -------- CHECKPOINT --------> finished 2700/7131 on user 617
# -------- CHECKPOINT --------> finished 2800/7131 on user 617
# -------- CHECKPOINT --------> finished 2900/7131 on user 617
# -------- CHECKPOINT --------> finished 3000/7131 on user 617
# -------- CHECKPOINT --------> finished 3100/7131 on user 617
# -------- CHECKPOINT --------> finished 3200/7131 on user 617
# -------- CHECKPOINT --------> finished 3300/7131 on user 617
# -------- CHECKPOINT --------> finished 3400/7131 on user 617
# -------- CHECKPOINT --------> finished 3500/7131 on user 617
# -------- CHECKPOINT --------> finished 3600/7131 on user 617
# -------- CHECKPOINT --------> finished 3700/7131 on user 617
# -------- CHECKPOINT --------> finished 3800/7131 on user 617
# -------- CHECKPOINT --------> finished 3900/7131 on user 617
# -------- CHECKPOINT --------> finished 4000/7131 on user 617
# -------- CHECKPOINT --------> finished 4100/7131 on user 617
# -------- CHECKPOINT --------> finished 4200/7131 on user 617
# -------- CHECKPOINT --------> finished 4300/7131 on user 617
# -------- CHECKPOINT --------> finished 4400/7131 on user 617
# -------- CHECKPOINT --------> finished 4500/7131 on user 617
# -------- CHECKPOINT --------> finished 4600/7131 on user 617
# -------- CHECKPOINT --------> finished 4700/7131 on user 617
# -------- CHECKPOINT --------> finished 4800/7131 on user 617
# -------- CHECKPOINT --------> finished 4900/7131 on user 617
# -------- CHECKPOINT --------> finished 5000/7131 on user 617
# -------- CHECKPOINT --------> finished 5100/7131 on user 617
# -------- CHECKPOINT --------> finished 5200/7131 on user 617
# -------- CHECKPOINT --------> finished 5300/7131 on user 617
# -------- CHECKPOINT --------> finished 5400/7131 on user 617
# -------- CHECKPOINT --------> finished 5500/7131 on user 617
# -------- CHECKPOINT --------> finished 5600/7131 on user 617
# -------- CHECKPOINT --------> finished 5700/7131 on user 617
# -------- CHECKPOINT --------> finished 5800/7131 on user 617
# -------- CHECKPOINT --------> finished 5900/7131 on user 617
# -------- CHECKPOINT --------> finished 6000/7131 on user 617
# -------- CHECKPOINT --------> finished 6100/7131 on user 617
# -------- CHECKPOINT --------> finished 6200/7131 on user 617
# -------- CHECKPOINT --------> finished 6300/7131 on user 617
# -------- CHECKPOINT --------> finished 6400/7131 on user 617
# -------- CHECKPOINT --------> finished 6500/7131 on user 617
# -------- CHECKPOINT --------> finished 6600/7131 on user 617
# -------- CHECKPOINT --------> finished 6700/7131 on user 617
# -------- CHECKPOINT --------> finished 6800/7131 on user 617
# -------- CHECKPOINT --------> finished 6900/7131 on user 617
# -------- CHECKPOINT --------> finished 7000/7131 on user 617
# -------- CHECKPOINT --------> finished 7100/7131 on user 617
# -------- CHECKPOINT --------> finished 100/223 on user 644
# -------- CHECKPOINT --------> finished 200/223 on user 644
# -------- CHECKPOINT --------> finished 100/323 on user 684
# -------- CHECKPOINT --------> finished 200/323 on user 684
# -------- CHECKPOINT --------> finished 300/323 on user 684
# -------- CHECKPOINT --------> finished 100/719 on user 685
# -------- CHECKPOINT --------> finished 200/719 on user 685
# -------- CHECKPOINT --------> finished 300/719 on user 685
# -------- CHECKPOINT --------> finished 400/719 on user 685
# -------- CHECKPOINT --------> finished 500/719 on user 685
# -------- CHECKPOINT --------> finished 600/719 on user 685
# -------- CHECKPOINT --------> finished 700/719 on user 685
# finished building followers for 700 users
# -------- CHECKPOINT --------> finished 100/138 on user 726
# -------- CHECKPOINT --------> finished 100/215 on user 747
# -------- CHECKPOINT --------> finished 200/215 on user 747
# -------- CHECKPOINT --------> finished 100/101 on user 756
# -------- CHECKPOINT --------> finished 100/253 on user 774
# -------- CHECKPOINT --------> finished 200/253 on user 774
# -------- CHECKPOINT --------> finished 100/162 on user 776
# -------- CHECKPOINT --------> finished 100/164 on user 778
# -------- CHECKPOINT --------> finished 100/159 on user 795
# finished building followers for 800 users
# -------- CHECKPOINT --------> finished 100/155 on user 807
# -------- CHECKPOINT --------> finished 100/104 on user 813
# -------- CHECKPOINT --------> finished 100/1624 on user 825
# -------- CHECKPOINT --------> finished 200/1624 on user 825
# -------- CHECKPOINT --------> finished 300/1624 on user 825
# -------- CHECKPOINT --------> finished 400/1624 on user 825
# -------- CHECKPOINT --------> finished 500/1624 on user 825
# -------- CHECKPOINT --------> finished 600/1624 on user 825
# -------- CHECKPOINT --------> finished 700/1624 on user 825
# -------- CHECKPOINT --------> finished 800/1624 on user 825
# -------- CHECKPOINT --------> finished 900/1624 on user 825
# -------- CHECKPOINT --------> finished 1000/1624 on user 825
# -------- CHECKPOINT --------> finished 1100/1624 on user 825
# -------- CHECKPOINT --------> finished 1200/1624 on user 825
# -------- CHECKPOINT --------> finished 1300/1624 on user 825
# -------- CHECKPOINT --------> finished 1400/1624 on user 825
# -------- CHECKPOINT --------> finished 1500/1624 on user 825
# -------- CHECKPOINT --------> finished 1600/1624 on user 825
# -------- CHECKPOINT --------> finished 100/116 on user 826
# -------- CHECKPOINT --------> finished 100/311 on user 842
# -------- CHECKPOINT --------> finished 200/311 on user 842
# -------- CHECKPOINT --------> finished 300/311 on user 842
# -------- CHECKPOINT --------> finished 100/298 on user 843
# -------- CHECKPOINT --------> finished 200/298 on user 843
# -------- CHECKPOINT --------> finished 100/239 on user 853
# -------- CHECKPOINT --------> finished 200/239 on user 853
# -------- CHECKPOINT --------> finished 100/109 on user 880
# -------- CHECKPOINT --------> finished 100/132 on user 891
# -------- CHECKPOINT --------> finished 100/640 on user 893
# -------- CHECKPOINT --------> finished 200/640 on user 893
# -------- CHECKPOINT --------> finished 300/640 on user 893
# -------- CHECKPOINT --------> finished 400/640 on user 893
# -------- CHECKPOINT --------> finished 500/640 on user 893
# -------- CHECKPOINT --------> finished 600/640 on user 893
# finished building followers for 900 users
# -------- CHECKPOINT --------> finished 100/106 on user 919
# -------- CHECKPOINT --------> finished 100/295 on user 929
# -------- CHECKPOINT --------> finished 200/295 on user 929
# -------- CHECKPOINT --------> finished 100/209 on user 945
# -------- CHECKPOINT --------> finished 200/209 on user 945
# -------- CHECKPOINT --------> finished 100/239 on user 946
# -------- CHECKPOINT --------> finished 200/239 on user 946
# -------- CHECKPOINT --------> finished 100/332 on user 956
# -------- CHECKPOINT --------> finished 200/332 on user 956
# -------- CHECKPOINT --------> finished 300/332 on user 956
# -------- CHECKPOINT --------> finished 100/131 on user 973
# -------- CHECKPOINT --------> finished 100/1011 on user 978
# -------- CHECKPOINT --------> finished 200/1011 on user 978
# -------- CHECKPOINT --------> finished 300/1011 on user 978
# -------- CHECKPOINT --------> finished 400/1011 on user 978
# -------- CHECKPOINT --------> finished 500/1011 on user 978
# -------- CHECKPOINT --------> finished 600/1011 on user 978
# -------- CHECKPOINT --------> finished 700/1011 on user 978
# -------- CHECKPOINT --------> finished 800/1011 on user 978
# -------- CHECKPOINT --------> finished 900/1011 on user 978
# -------- CHECKPOINT --------> finished 1000/1011 on user 978
# finished building followers for 1000 users
# -------- CHECKPOINT --------> finished 100/385 on user 1023
# -------- CHECKPOINT --------> finished 200/385 on user 1023
# -------- CHECKPOINT --------> finished 300/385 on user 1023
# -------- CHECKPOINT --------> finished 100/3054 on user 1060
# -------- CHECKPOINT --------> finished 200/3054 on user 1060
# -------- CHECKPOINT --------> finished 300/3054 on user 1060
# -------- CHECKPOINT --------> finished 400/3054 on user 1060
# -------- CHECKPOINT --------> finished 500/3054 on user 1060
# -------- CHECKPOINT --------> finished 600/3054 on user 1060
# -------- CHECKPOINT --------> finished 700/3054 on user 1060
# -------- CHECKPOINT --------> finished 800/3054 on user 1060
# -------- CHECKPOINT --------> finished 900/3054 on user 1060
# -------- CHECKPOINT --------> finished 1000/3054 on user 1060
# -------- CHECKPOINT --------> finished 1100/3054 on user 1060
# -------- CHECKPOINT --------> finished 1200/3054 on user 1060
# -------- CHECKPOINT --------> finished 1300/3054 on user 1060
# -------- CHECKPOINT --------> finished 1400/3054 on user 1060
# -------- CHECKPOINT --------> finished 1500/3054 on user 1060
# -------- CHECKPOINT --------> finished 1600/3054 on user 1060
# -------- CHECKPOINT --------> finished 1700/3054 on user 1060
# -------- CHECKPOINT --------> finished 1800/3054 on user 1060
# -------- CHECKPOINT --------> finished 1900/3054 on user 1060
# -------- CHECKPOINT --------> finished 2000/3054 on user 1060
# -------- CHECKPOINT --------> finished 2100/3054 on user 1060
# -------- CHECKPOINT --------> finished 2200/3054 on user 1060
# -------- CHECKPOINT --------> finished 2300/3054 on user 1060
# -------- CHECKPOINT --------> finished 2400/3054 on user 1060
# -------- CHECKPOINT --------> finished 2500/3054 on user 1060
# -------- CHECKPOINT --------> finished 2600/3054 on user 1060
# -------- CHECKPOINT --------> finished 2700/3054 on user 1060
# -------- CHECKPOINT --------> finished 2800/3054 on user 1060
# -------- CHECKPOINT --------> finished 2900/3054 on user 1060
# -------- CHECKPOINT --------> finished 3000/3054 on user 1060
# -------- CHECKPOINT --------> finished 100/110 on user 1063
# finished building followers for 1100 users
# -------- CHECKPOINT --------> finished 100/285 on user 1109
# -------- CHECKPOINT --------> finished 200/285 on user 1109
# -------- CHECKPOINT --------> finished 100/541 on user 1152
# -------- CHECKPOINT --------> finished 200/541 on user 1152
# -------- CHECKPOINT --------> finished 300/541 on user 1152
# -------- CHECKPOINT --------> finished 400/541 on user 1152
# -------- CHECKPOINT --------> finished 500/541 on user 1152
# -------- CHECKPOINT --------> finished 100/121 on user 1163
# -------- CHECKPOINT --------> finished 100/131 on user 1199
# finished building followers for 1200 users
# -------- CHECKPOINT --------> finished 100/640 on user 1201
# -------- CHECKPOINT --------> finished 200/640 on user 1201
# -------- CHECKPOINT --------> finished 300/640 on user 1201
# -------- CHECKPOINT --------> finished 400/640 on user 1201
# -------- CHECKPOINT --------> finished 500/640 on user 1201
# -------- CHECKPOINT --------> finished 600/640 on user 1201
# -------- CHECKPOINT --------> finished 100/154 on user 1215
# -------- CHECKPOINT --------> finished 100/355 on user 1227
# -------- CHECKPOINT --------> finished 200/355 on user 1227
# -------- CHECKPOINT --------> finished 300/355 on user 1227
# -------- CHECKPOINT --------> finished 100/373 on user 1228
# -------- CHECKPOINT --------> finished 200/373 on user 1228
# -------- CHECKPOINT --------> finished 300/373 on user 1228
# -------- CHECKPOINT --------> finished 100/328 on user 1235
# -------- CHECKPOINT --------> finished 200/328 on user 1235
# -------- CHECKPOINT --------> finished 300/328 on user 1235
# -------- CHECKPOINT --------> finished 100/314 on user 1243
# -------- CHECKPOINT --------> finished 200/314 on user 1243
# -------- CHECKPOINT --------> finished 300/314 on user 1243
# -------- CHECKPOINT --------> finished 100/1025 on user 1249
# -------- CHECKPOINT --------> finished 200/1025 on user 1249
# -------- CHECKPOINT --------> finished 300/1025 on user 1249
# -------- CHECKPOINT --------> finished 400/1025 on user 1249
# -------- CHECKPOINT --------> finished 500/1025 on user 1249
# -------- CHECKPOINT --------> finished 600/1025 on user 1249
# -------- CHECKPOINT --------> finished 700/1025 on user 1249
# -------- CHECKPOINT --------> finished 800/1025 on user 1249
# -------- CHECKPOINT --------> finished 900/1025 on user 1249
# -------- CHECKPOINT --------> finished 1000/1025 on user 1249
# -------- CHECKPOINT --------> finished 100/223 on user 1257
# -------- CHECKPOINT --------> finished 200/223 on user 1257
# -------- CHECKPOINT --------> finished 100/105 on user 1264
# -------- CHECKPOINT --------> finished 100/169 on user 1289
# finished building followers for 1300 users
# -------- CHECKPOINT --------> finished 100/259 on user 1306
# -------- CHECKPOINT --------> finished 200/259 on user 1306
# -------- CHECKPOINT --------> finished 100/1013 on user 1331
# -------- CHECKPOINT --------> finished 200/1013 on user 1331
# -------- CHECKPOINT --------> finished 300/1013 on user 1331
# -------- CHECKPOINT --------> finished 400/1013 on user 1331
# -------- CHECKPOINT --------> finished 500/1013 on user 1331
# -------- CHECKPOINT --------> finished 600/1013 on user 1331
# -------- CHECKPOINT --------> finished 700/1013 on user 1331
# -------- CHECKPOINT --------> finished 800/1013 on user 1331
# -------- CHECKPOINT --------> finished 900/1013 on user 1331
# -------- CHECKPOINT --------> finished 1000/1013 on user 1331
# -------- CHECKPOINT --------> finished 100/127 on user 1360
# -------- CHECKPOINT --------> finished 100/142 on user 1378
# finished building followers for 1400 users
# -------- CHECKPOINT --------> finished 100/239 on user 1471
# -------- CHECKPOINT --------> finished 200/239 on user 1471
# -------- CHECKPOINT --------> finished 100/138 on user 1473
# -------- CHECKPOINT --------> finished 100/243 on user 1482
# -------- CHECKPOINT --------> finished 200/243 on user 1482
# -------- CHECKPOINT --------> finished 100/359 on user 1488
# -------- CHECKPOINT --------> finished 200/359 on user 1488
# -------- CHECKPOINT --------> finished 300/359 on user 1488
# -------- CHECKPOINT --------> finished 100/157 on user 1495
# finished building followers for 1500 users
# -------- CHECKPOINT --------> finished 100/101 on user 1506
# -------- CHECKPOINT --------> finished 100/147 on user 1519
# -------- CHECKPOINT --------> finished 100/204 on user 1526
# -------- CHECKPOINT --------> finished 200/204 on user 1526
# -------- CHECKPOINT --------> finished 100/169 on user 1565
# -------- CHECKPOINT --------> finished 100/204 on user 1573
# -------- CHECKPOINT --------> finished 200/204 on user 1573
# -------- CHECKPOINT --------> finished 100/235 on user 1580
# -------- CHECKPOINT --------> finished 200/235 on user 1580
# -------- CHECKPOINT --------> finished 100/375 on user 1590
# -------- CHECKPOINT --------> finished 200/375 on user 1590
# -------- CHECKPOINT --------> finished 300/375 on user 1590
# finished building followers for 1600 users
# -------- CHECKPOINT --------> finished 100/128 on user 1603
# -------- CHECKPOINT --------> finished 100/164 on user 1609
# -------- CHECKPOINT --------> finished 100/259 on user 1681
# -------- CHECKPOINT --------> finished 200/259 on user 1681
# -------- CHECKPOINT --------> finished 100/253 on user 1682
# -------- CHECKPOINT --------> finished 200/253 on user 1682
# -------- CHECKPOINT --------> finished 100/167 on user 1689
# -------- CHECKPOINT --------> finished 100/168 on user 1698
# finished building followers for 1700 users
# -------- CHECKPOINT --------> finished 100/203 on user 1709
# -------- CHECKPOINT --------> finished 200/203 on user 1709
# -------- CHECKPOINT --------> finished 100/142 on user 1722
# -------- CHECKPOINT --------> finished 100/6103 on user 1729
# -------- CHECKPOINT --------> finished 200/6103 on user 1729
# -------- CHECKPOINT --------> finished 300/6103 on user 1729
# -------- CHECKPOINT --------> finished 400/6103 on user 1729
# -------- CHECKPOINT --------> finished 500/6103 on user 1729
# -------- CHECKPOINT --------> finished 600/6103 on user 1729
# -------- CHECKPOINT --------> finished 700/6103 on user 1729
# -------- CHECKPOINT --------> finished 800/6103 on user 1729
# -------- CHECKPOINT --------> finished 900/6103 on user 1729
# -------- CHECKPOINT --------> finished 1000/6103 on user 1729
# -------- CHECKPOINT --------> finished 1100/6103 on user 1729
# -------- CHECKPOINT --------> finished 1200/6103 on user 1729
# -------- CHECKPOINT --------> finished 1300/6103 on user 1729
# -------- CHECKPOINT --------> finished 1400/6103 on user 1729
# -------- CHECKPOINT --------> finished 1500/6103 on user 1729
# -------- CHECKPOINT --------> finished 1600/6103 on user 1729
# -------- CHECKPOINT --------> finished 1700/6103 on user 1729
# -------- CHECKPOINT --------> finished 1800/6103 on user 1729
# -------- CHECKPOINT --------> finished 1900/6103 on user 1729
# -------- CHECKPOINT --------> finished 2000/6103 on user 1729
# -------- CHECKPOINT --------> finished 2100/6103 on user 1729
# -------- CHECKPOINT --------> finished 2200/6103 on user 1729
# -------- CHECKPOINT --------> finished 2300/6103 on user 1729
# -------- CHECKPOINT --------> finished 2400/6103 on user 1729
# -------- CHECKPOINT --------> finished 2500/6103 on user 1729
# -------- CHECKPOINT --------> finished 2600/6103 on user 1729
# -------- CHECKPOINT --------> finished 2700/6103 on user 1729
# -------- CHECKPOINT --------> finished 2800/6103 on user 1729
# -------- CHECKPOINT --------> finished 2900/6103 on user 1729
# -------- CHECKPOINT --------> finished 3000/6103 on user 1729
# -------- CHECKPOINT --------> finished 3100/6103 on user 1729
# -------- CHECKPOINT --------> finished 3200/6103 on user 1729
# -------- CHECKPOINT --------> finished 3300/6103 on user 1729
# -------- CHECKPOINT --------> finished 3400/6103 on user 1729
# -------- CHECKPOINT --------> finished 3500/6103 on user 1729
# -------- CHECKPOINT --------> finished 3600/6103 on user 1729
# -------- CHECKPOINT --------> finished 3700/6103 on user 1729
# -------- CHECKPOINT --------> finished 3800/6103 on user 1729
# -------- CHECKPOINT --------> finished 3900/6103 on user 1729
# -------- CHECKPOINT --------> finished 4000/6103 on user 1729
# -------- CHECKPOINT --------> finished 4100/6103 on user 1729
# -------- CHECKPOINT --------> finished 4200/6103 on user 1729
# -------- CHECKPOINT --------> finished 4300/6103 on user 1729
# -------- CHECKPOINT --------> finished 4400/6103 on user 1729
# -------- CHECKPOINT --------> finished 4500/6103 on user 1729
# -------- CHECKPOINT --------> finished 4600/6103 on user 1729
# -------- CHECKPOINT --------> finished 4700/6103 on user 1729
# -------- CHECKPOINT --------> finished 4800/6103 on user 1729
# -------- CHECKPOINT --------> finished 4900/6103 on user 1729
# -------- CHECKPOINT --------> finished 5000/6103 on user 1729
# -------- CHECKPOINT --------> finished 5100/6103 on user 1729
# -------- CHECKPOINT --------> finished 5200/6103 on user 1729
# -------- CHECKPOINT --------> finished 5300/6103 on user 1729
# -------- CHECKPOINT --------> finished 5400/6103 on user 1729
# -------- CHECKPOINT --------> finished 5500/6103 on user 1729
# -------- CHECKPOINT --------> finished 5600/6103 on user 1729
# -------- CHECKPOINT --------> finished 5700/6103 on user 1729
# -------- CHECKPOINT --------> finished 5800/6103 on user 1729
# -------- CHECKPOINT --------> finished 5900/6103 on user 1729
# -------- CHECKPOINT --------> finished 6000/6103 on user 1729
# -------- CHECKPOINT --------> finished 6100/6103 on user 1729
# -------- CHECKPOINT --------> finished 100/717 on user 1733
# -------- CHECKPOINT --------> finished 200/717 on user 1733
# -------- CHECKPOINT --------> finished 300/717 on user 1733
# -------- CHECKPOINT --------> finished 400/717 on user 1733
# -------- CHECKPOINT --------> finished 500/717 on user 1733
# -------- CHECKPOINT --------> finished 600/717 on user 1733
# -------- CHECKPOINT --------> finished 700/717 on user 1733
# -------- CHECKPOINT --------> finished 100/1804 on user 1753
# -------- CHECKPOINT --------> finished 200/1804 on user 1753
# -------- CHECKPOINT --------> finished 300/1804 on user 1753
# -------- CHECKPOINT --------> finished 400/1804 on user 1753
# -------- CHECKPOINT --------> finished 500/1804 on user 1753
# -------- CHECKPOINT --------> finished 600/1804 on user 1753
# -------- CHECKPOINT --------> finished 700/1804 on user 1753
# -------- CHECKPOINT --------> finished 800/1804 on user 1753
# -------- CHECKPOINT --------> finished 900/1804 on user 1753
# -------- CHECKPOINT --------> finished 1000/1804 on user 1753
# -------- CHECKPOINT --------> finished 1100/1804 on user 1753
# -------- CHECKPOINT --------> finished 1200/1804 on user 1753
# -------- CHECKPOINT --------> finished 1300/1804 on user 1753
# -------- CHECKPOINT --------> finished 1400/1804 on user 1753
# -------- CHECKPOINT --------> finished 1500/1804 on user 1753
# -------- CHECKPOINT --------> finished 1600/1804 on user 1753
# -------- CHECKPOINT --------> finished 1700/1804 on user 1753
# -------- CHECKPOINT --------> finished 1800/1804 on user 1753
# -------- CHECKPOINT --------> finished 100/2490 on user 1755
# -------- CHECKPOINT --------> finished 200/2490 on user 1755
# -------- CHECKPOINT --------> finished 300/2490 on user 1755
# -------- CHECKPOINT --------> finished 400/2490 on user 1755
# -------- CHECKPOINT --------> finished 500/2490 on user 1755
# -------- CHECKPOINT --------> finished 600/2490 on user 1755
# -------- CHECKPOINT --------> finished 700/2490 on user 1755
# -------- CHECKPOINT --------> finished 800/2490 on user 1755
# -------- CHECKPOINT --------> finished 900/2490 on user 1755
# -------- CHECKPOINT --------> finished 1000/2490 on user 1755
# -------- CHECKPOINT --------> finished 1100/2490 on user 1755
# -------- CHECKPOINT --------> finished 1200/2490 on user 1755
# -------- CHECKPOINT --------> finished 1300/2490 on user 1755
# -------- CHECKPOINT --------> finished 1400/2490 on user 1755
# -------- CHECKPOINT --------> finished 1500/2490 on user 1755
# -------- CHECKPOINT --------> finished 1600/2490 on user 1755
# -------- CHECKPOINT --------> finished 1700/2490 on user 1755
# -------- CHECKPOINT --------> finished 1800/2490 on user 1755
# -------- CHECKPOINT --------> finished 1900/2490 on user 1755
# -------- CHECKPOINT --------> finished 2000/2490 on user 1755
# -------- CHECKPOINT --------> finished 2100/2490 on user 1755
# -------- CHECKPOINT --------> finished 2200/2490 on user 1755
# -------- CHECKPOINT --------> finished 2300/2490 on user 1755
# -------- CHECKPOINT --------> finished 2400/2490 on user 1755
# -------- CHECKPOINT --------> finished 100/141 on user 1767
# -------- CHECKPOINT --------> finished 100/267 on user 1771
# -------- CHECKPOINT --------> finished 200/267 on user 1771
# -------- CHECKPOINT --------> finished 100/149 on user 1774
# -------- CHECKPOINT --------> finished 100/234 on user 1778
# -------- CHECKPOINT --------> finished 200/234 on user 1778
# finished building followers for 1800 users
# -------- CHECKPOINT --------> finished 100/755 on user 1810
# -------- CHECKPOINT --------> finished 200/755 on user 1810
# -------- CHECKPOINT --------> finished 300/755 on user 1810
# -------- CHECKPOINT --------> finished 400/755 on user 1810
# -------- CHECKPOINT --------> finished 500/755 on user 1810
# -------- CHECKPOINT --------> finished 600/755 on user 1810
# -------- CHECKPOINT --------> finished 700/755 on user 1810
# -------- CHECKPOINT --------> finished 100/107 on user 1812
# -------- CHECKPOINT --------> finished 100/480 on user 1813
# -------- CHECKPOINT --------> finished 200/480 on user 1813
# -------- CHECKPOINT --------> finished 300/480 on user 1813
# -------- CHECKPOINT --------> finished 400/480 on user 1813
# -------- CHECKPOINT --------> finished 100/510 on user 1851
# -------- CHECKPOINT --------> finished 200/510 on user 1851
# -------- CHECKPOINT --------> finished 300/510 on user 1851
# -------- CHECKPOINT --------> finished 400/510 on user 1851
# -------- CHECKPOINT --------> finished 500/510 on user 1851
# -------- CHECKPOINT --------> finished 100/746 on user 1862
# -------- CHECKPOINT --------> finished 200/746 on user 1862
# -------- CHECKPOINT --------> finished 300/746 on user 1862
# -------- CHECKPOINT --------> finished 400/746 on user 1862
# -------- CHECKPOINT --------> finished 500/746 on user 1862
# -------- CHECKPOINT --------> finished 600/746 on user 1862
# -------- CHECKPOINT --------> finished 700/746 on user 1862
# -------- CHECKPOINT --------> finished 100/231 on user 1863
# -------- CHECKPOINT --------> finished 200/231 on user 1863
# -------- CHECKPOINT --------> finished 100/550 on user 1875
# -------- CHECKPOINT --------> finished 200/550 on user 1875
# -------- CHECKPOINT --------> finished 300/550 on user 1875
# -------- CHECKPOINT --------> finished 400/550 on user 1875
# -------- CHECKPOINT --------> finished 500/550 on user 1875
# -------- CHECKPOINT --------> finished 100/590 on user 1882
# -------- CHECKPOINT --------> finished 200/590 on user 1882
# -------- CHECKPOINT --------> finished 300/590 on user 1882
# -------- CHECKPOINT --------> finished 400/590 on user 1882
# -------- CHECKPOINT --------> finished 500/590 on user 1882
# -------- CHECKPOINT --------> finished 100/10156 on user 1885
# -------- CHECKPOINT --------> finished 200/10156 on user 1885
# -------- CHECKPOINT --------> finished 300/10156 on user 1885
# -------- CHECKPOINT --------> finished 400/10156 on user 1885
# -------- CHECKPOINT --------> finished 500/10156 on user 1885
# -------- CHECKPOINT --------> finished 600/10156 on user 1885
# -------- CHECKPOINT --------> finished 700/10156 on user 1885
# -------- CHECKPOINT --------> finished 800/10156 on user 1885
# -------- CHECKPOINT --------> finished 900/10156 on user 1885
# -------- CHECKPOINT --------> finished 1000/10156 on user 1885
# -------- CHECKPOINT --------> finished 1100/10156 on user 1885
# -------- CHECKPOINT --------> finished 1200/10156 on user 1885
# -------- CHECKPOINT --------> finished 1300/10156 on user 1885
# -------- CHECKPOINT --------> finished 1400/10156 on user 1885
# -------- CHECKPOINT --------> finished 1500/10156 on user 1885
# -------- CHECKPOINT --------> finished 1600/10156 on user 1885
# -------- CHECKPOINT --------> finished 1700/10156 on user 1885
# -------- CHECKPOINT --------> finished 1800/10156 on user 1885
# -------- CHECKPOINT --------> finished 1900/10156 on user 1885
# -------- CHECKPOINT --------> finished 2000/10156 on user 1885
# -------- CHECKPOINT --------> finished 2100/10156 on user 1885
# -------- CHECKPOINT --------> finished 2200/10156 on user 1885
# -------- CHECKPOINT --------> finished 2300/10156 on user 1885
# -------- CHECKPOINT --------> finished 2400/10156 on user 1885
# -------- CHECKPOINT --------> finished 2500/10156 on user 1885
# -------- CHECKPOINT --------> finished 2600/10156 on user 1885
# -------- CHECKPOINT --------> finished 2700/10156 on user 1885
# -------- CHECKPOINT --------> finished 2800/10156 on user 1885
# -------- CHECKPOINT --------> finished 2900/10156 on user 1885
# -------- CHECKPOINT --------> finished 3000/10156 on user 1885
# -------- CHECKPOINT --------> finished 3100/10156 on user 1885
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-04fa7f157859> in <module>()
#       1 users, followers, following = parse_twitter_users()
#       2 print('building network now...')
# ----> 3 edges = build_twitter_network(users, followers, following)
#
# <ipython-input-69-e31216e4d0c2> in build_twitter_network(users, outdegrees, indegrees)
#      25
#      26                 new_follower = random.choice(list(down_counter.keys()))
# ---> 27                 if int(down_counter[new_follower]) > 0:
#      28                     edges[user].append(new_follower)
#      29                     down_counter[new_follower] = int(down_counter[new_follower]) - 1
#
# ValueError: invalid literal for int() with base 10: 'following_count'

# %%
# checkpoint: have set of users, have dict of { user: followers }
# generate artificial tweet cascade -> analyze first k retweets,
